# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Misiriya Shahul Hameed__
# Data Scientist

# %% [markdown]
# _Data Science is a field in Artificial Intelligence, where raw Data is analyzed by curating, organizing, pre-processing and exploring each feature, thereby gaining interesting insights into why things happened the way they did. This part of Data Science is so interesting, it piques my curiosity and keeps me engaged. Using these insights to train and generate predictive models to classify fresh data, can help in so many Bsuiness models, particularly the Health industry, and thus, this can even save lives. This is why I love to be part of an active Data Science Community, and pursue my career in it._

# %% [markdown]
# ### Printing a combination of String and Sum of Integers in Python

# %%
print("I possess "+ str(5+6+2) +" years of experience in roles such as a Lecturer, a Researcher, and a Developer")
# Out:
# I possess 13 years of experience in roles such as a Lecturer, a Researcher, and a Developer

# %% [markdown]
# During my Research Experience, I have used the following skills, to name a few:
# 1. Exploratory Data Analysis
# 2. Data Wrangling
# 3. Algorithm Evaluation
# 4. Machine Learning
#
# During my teaching experience, I did Data Analysis, for analyzing results of students. At the time, I used the following tools:
# - MS-Excel
# - MS-Powerpoint
# - Google Sheets
# - Google Forms (for feedbacks)
#
# #### Here is a table displaying skills that I am highly proficient in:
#
# |Skill|Proficiency|
# |--------------|---------------|
# |Machine Learning|Proficient|
# |Microsoft Excel|Proficient|
# |Adobe Photoshop|Proficient|
# |Spyder|Proficient|
# |SQL|Proficient|
#
# Here are some Links to my profile:
#
# [LinkedIn Profile](https://www.linkedin.com/in/misiriya-shahul-hameed-b3957875)
# [GitHub Profile](https://github.com/misiriya)
# [Wordpress Link](https://misiriya.wordpress.com/about-me/)
#
# I also received an IBM Badge:
# [![Cognitive_Class_-_What_is_Data_Science.png](attachment:Cognitive_Class_-_What_is_Data_Science.png)](https://www.credly.com/badges/f7f99130-a870-4e7d-b737-a6d5b58a50c6/linked_in_profile)
